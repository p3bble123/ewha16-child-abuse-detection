# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone 'https://github.com/AlexeyAB/darknet.git' '/content/drive/MyDrive/2021_캡스톤디자인프로젝트_16/YOLO_1104/darknet'
# Out:
# Cloning into '/content/drive/MyDrive/2021_캡스톤디자인프로젝트_16/YOLO_1104/darknet'...
# remote: Enumerating objects: 15339, done.
# remote: Total 15339 (delta 0), reused 0 (delta 0), pack-reused 15339
# Receiving objects: 100% (15339/15339), 13.92 MiB | 8.92 MiB/s, done.
# Resolving deltas: 100% (10384/10384), done.
# Checking out files: 100% (2049/2049), done.

# %%
# %cd /content/drive/MyDrive/2021_캡스톤디자인프로젝트_16/YOLO_1104/darknet
# Out:
# /content/drive/MyDrive/2021_캡스톤디자인프로젝트_16/YOLO_1104/darknet

# %%
# 참고: https://arnon.dk/matching-sm-architectures-arch-and-gencode-for-various-nvidia-cards/

# !sed -i 's/OPENCV=0/OPENCV=1/' Makefile
# !sed -i 's/GPU=0/GPU=1/' Makefile
# !sed -i 's/CUDNN=0/CUDNN=1/' Makefile

# %%
# darknet 업로드하고 나서,
# [MakeFile] edit arch before running (last updated 21.05.28)
# (코랩 말도없이 자꾸 dependencies 갈아치운다는 증언이 여기저기... 필요에 따라 에러출력 확인하고 수정해야 됨)
# 참고: https://arnon.dk/matching-sm-architectures-arch-and-gencode-for-various-nvidia-cards/
# !make
# !chmod +x ./darknet
# Out:
# chmod +x *.sh
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/image_opencv.cpp -o obj/image_opencv.o
# ./src/image_opencv.cpp: In function ‘void draw_detections_cv_v3(void**, detection*, int, float, char**, image**, int, int)’:
# ./src/image_opencv.cpp:946:23: warning: variable ‘rgb’ set but not used [-Wunused-but-set-variable]
#                  float rgb[3];
#                        ^~~
# ./src/image_opencv.cpp: In function ‘void draw_train_loss(char*, void**, int, float, float, int, int, float, int, char*, float, int, int, double)’:
# ./src/image_opencv.cpp:1147:13: warning: this ‘if’ clause does not guard... [-Wmisleading-indentation]
#              if (iteration_old == 0)
#              ^~
# ...

# %%
# %cd /content/drive/MyDrive/2021_캡스톤디자인프로젝트_16/YOLO_1104
# Out:
# /content/drive/MyDrive/2021_캡스톤디자인프로젝트_16/YOLO_1104

# %%
# yolov3_custom_train.cfg 수정
# yolov3_custom_train_last.weights 이어서 학습
# !darknet/darknet detector train custom_data/labelled_data.data darknet/cfg/yolov3_custom.cfg backup/yolov3_custom_last.weights -dont_show -map
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.792509), count: 1, class_loss = 0.019646, iou_loss = 0.019698, total_loss = 0.039344
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.001459, iou_loss = 0.000000, total_loss = 0.001459
#  total_bbox = 359816, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.829941), count: 3, class_loss = 0.041885, iou_loss = 0.054393, total_loss = 0.096278
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.830897), count: 1, class_loss = 0.185958, iou_loss = 0.047107, total_loss = 0.233065
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000000, iou_loss = 0.000000, total_loss = 0.000000
#  total_bbox = 359820, rewritten_bbox = 0.000000 %
# ...
